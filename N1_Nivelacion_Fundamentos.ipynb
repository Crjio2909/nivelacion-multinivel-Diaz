# %% [markdown]
# <a href="https://colab.research.google.com/github/Crjio2909/nivelacion-multinivel-Diaz/blob/master/N1_Nivelacion_Fundamentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Variables del personaje RPG
nombre = 'Gandalf'
nivel = 5
vida = 80.0
mana = 120
clase = 'Mago'
puntos_ataque = 15
puntos_defensa = 10
# Verificar tipos
print(type(nombre))   # <class 'str'>
print(type(clase))   # <class 'str'>
print(type(nivel))    # <class 'int'>
print(type(vida))     # <class 'float'>
print(type(mana)) # <class 'bool'>
print(f'{nombre} {clase} (Nv.{nivel}) - Vida: {vida} Mana: {mana} ')
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'int'>
# Gandalf Mago (Nv.5) - Vida: 80.0 Mana: 120
